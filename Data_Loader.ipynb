# %% [markdown]
# <a href="https://colab.research.google.com/github/Babisama1/Membuat-design/blob/Data_loader/Data_Loader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MENGAMBIL DATA SET DARI INTERNET
# !pip install datasets

from datasets import load_dataset
from torch.utils.data import DataLoader, Dataset
import torch

#Kita ambil dataset puisi/teks pendek misal tiny_shakespeare

dataset_raw = load_dataset("wikitext", "wikitext-2-raw-v1", split="train")

#MEMBUAT PABRIK TOKEN
# Ambil beberapa teks dulu
text_sample = "".join(dataset_raw['text'][:1000])

# Ambil semua karakter unik
chars = sorted(list(set(text_sample)))

# Buat kamus karakter ke angka
char_to_int = {ch: i for i, ch in enumerate(chars)}
int_to_char = {i: ch for i, ch in enumerate(chars)}

print("Jumlah karakter unik:", len(chars))

def encode(s): return [char_to_int[c] for c in s]

data_angka = torch.tensor(encode(dataset_raw['text'][5]), dtype=torch.long)
print(f"Teks tadi sekarang jadi {data_angka[:20]}")

#MEMBUAT TRUK DATA LOADER
class TextDataset(Dataset):
  def __init__(self, data, seq_length):
    self.data = data
    self.seq_length = seq_length

  def __len__(self):
    return len(self.data) - self.seq_length

  def __getitem__(self, idx):
    x = self.data[idx : idx + self.seq_length]

    y = self.data[idx + 1 : idx + self.seq_length + 1]
    return x, y

#pengaturan
ukuran_potongan = 8
ukuran_kotak = 32

dataset_siap = TextDataset(data_angka, ukuran_potongan)
truck_data = DataLoader(dataset_siap, batch_size=ukuran_kotak, shuffle=True)

#cek isi truck
input_contoh, target_contoh = next(iter(truck_data))
print(f"Ukuran batch yang dibawa truck : {input_contoh.shape}")
# Out:
# ...
# Jumlah karakter unik: 154
# Teks tadi sekarang jadi tensor([ 1, 38, 77,  1, 70, 62, 77,  1, 80, 66, 77, 65,  1, 73, 72, 76, 66, 77,
#         66, 79])
# Ukuran batch yang dibawa truck : torch.Size([32, 8])

# %% [markdown]
# #MENGAMBIL DATA SET DARI INTERNET
# !pip install datasets
#
# from datasets import load_dataset
# from torch.utils.data import DataLoader, Dataset
# import torch
#
# #Kita ambil dataset puisi/teks pendek misal tiny_shakespeare
#
# dataset_raw = load_dataset("wikitext", "wikitext-2-raw-v1", split="train")
# …
# #cek isi truck
# input_contoh, target_contoh = next(iter(truck_data))
# print(f"Ukuran batch yang dibawa truck : {input_contoh.shape}")

# %%
#MENGAMBIL DATA SET DARI INTERNET
# !pip install datasets

from datasets import load_dataset
from torch.utils.data import DataLoader, Dataset
import torch

#Kita ambil dataset puisi/teks pendek misal tiny_shakespeare

dataset_raw = load_dataset("wikitext", "wikitext-2-raw-v1", split="train")

#MEMBUAT PABRIK TOKEN
# Ambil beberapa teks dulu
text_sample = "".join(dataset_raw['text'][:1000])

# Ambil semua karakter unik
chars = sorted(list(set(text_sample)))

# Buat kamus karakter ke angka
char_to_int = {ch: i for i, ch in enumerate(chars)}
int_to_char = {i: ch for i, ch in enumerate(chars)}

print("Jumlah karakter unik:", len(chars))

def encode(s): return [char_to_int[c] for c in s]

data_angka = torch.tensor(encode(dataset_raw['text'][5]), dtype=torch.long)
print(f"Teks tadi sekarang jadi {data_angka[:20]}")

#MEMBUAT TRUK DATA LOADER
class TextDataset(Dataset):
  def __init__(self, data, seq_length):
    self.data = data
    self.seq_length = seq_length

  def __len__(self):
    return len(self.data) - self.seq_length

  def __getitem__(self, idx):
    x = self.data[idx : idx + self.seq_length]

    y = self.data[idx + 1 : idx + self.seq_length + 1]
    return x, y

#pengaturan
ukuran_potongan = 8
ukuran_kotak = 32

dataset_siap = TextDataset(data_angka, ukuran_potongan)
truck_data = DataLoader(dataset_siap, batch_size=ukuran_kotak, shuffle=True)

#cek isi truck
input_contoh, target_contoh = next(iter(truck_data))
print(f"Ukuran batch yang dibawa truck : {input_contoh.shape}")
# Out:
# ...
# Jumlah karakter unik: 154
# Teks tadi sekarang jadi tensor([ 1, 38, 77,  1, 70, 62, 77,  1, 80, 66, 77, 65,  1, 73, 72, 76, 66, 77,
#         66, 79])
# Ukuran batch yang dibawa truck : torch.Size([32, 8])
